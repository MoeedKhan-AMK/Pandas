# %% [markdown]
# ## Interacting With CSV files in Pandas
# #### READING CSV FILE
# - read_csv Parameters Arguements
# #### WRITING/EDITING CSV FILE

# %% [markdown]
# ### WRITING CSV FILE
#
# - Working as Data Analyst/ Data Scientist, often there are scenario where you're provided with raw data.
# - For example, Raw Financial Metric, Raw Data, Raw prices data, Raw Revenue data and so on.
# - You will have to develop **`Derived CSV File`**.
# - This **`Derived CSV File`** is a dervied file, created professionaly from raw data file.
# - Syntax **``**

# %%
import pandas as pd
import csv

# %%
df = pd.read_csv('TSLA.csv')
df
# Out:
#             Date         Open         High         Low        Close  \
# 0     29/06/2010     3.800000     5.000000    3.508000     4.778000
# 1     30/06/2010     5.158000     6.084000    2.996000     4.766000
# 2     01/07/2010     5.000000     5.184000    4.054000     4.392000
# 3     02/07/2010     2.996000     4.620000    3.742000     3.840000
# 4     06/07/2010     4.000000     4.000000   -2.000000     3.222000
# ...          ...          ...          ...         ...          ...
# 2951  18/03/2022   874.489990   907.849976  867.390015   905.390015
# 2952  21/03/2022   914.979980   942.849976  907.090027   921.159973
# 2953  22/03/2022   930.000000   997.859985  921.750000   993.979980
# 2954  23/03/2022   979.940002  1040.699951  976.400024   999.109985
# 2955  24/03/2022  1009.729980  1024.489990  988.799988  1013.919983
#
#         Adj Close    Volume  \
# 0        4.778000  93831500
# 1        4.766000  85935500
# 2        4.392000  41094000
# 3        3.840000  25699000
# ...

# %% [markdown]
# Writing/Adding Daily Price Change into CSV file.
# - Daily Price Change = `Close − Open`
# - Avg Stock Price OR midpoint = `Avg Price = High + Low /2`

# %%
df["change"] = df["Close"]-df["Open"]   #Daily Price Change
df["avg price"] = df["High"] + df["Low"] / 2
df
# Out:
#             Date         Open         High         Low        Close  \
# 0     29/06/2010     3.800000     5.000000    3.508000     4.778000
# 1     30/06/2010     5.158000     6.084000    2.996000     4.766000
# 2     01/07/2010     5.000000     5.184000    4.054000     4.392000
# 3     02/07/2010     2.996000     4.620000    3.742000     3.840000
# 4     06/07/2010     4.000000     4.000000   -2.000000     3.222000
# ...          ...          ...          ...         ...          ...
# 2951  18/03/2022   874.489990   907.849976  867.390015   905.390015
# 2952  21/03/2022   914.979980   942.849976  907.090027   921.159973
# 2953  22/03/2022   930.000000   997.859985  921.750000   993.979980
# 2954  23/03/2022   979.940002  1040.699951  976.400024   999.109985
# 2955  24/03/2022  1009.729980  1024.489990  988.799988  1013.919983
#
#         Adj Close    Volume  \
# 0        4.778000  93831500
# 1        4.766000  85935500
# 2        4.392000  41094000
# 3        3.840000  25699000
# ...

# %% [markdown]
# # Using `.loc[]` and `.iloc[]` to fetch rows
#
# - Both .loc and .iloc are essential attributes of Pandas DataFrames
# - Both are used for selecting specific subsets of data.
# - Their purpose is to access and enable manipulating a specific part of the DataFrame instead of the whole DataFrame.
#
# - `loc[]` uses a label to point to a row, column or cell, whereas `.iloc[]` uses the numeric position.
# - `df.loc[row_indexer, column_indexer]`

# %%
import pandas as pd
import csv

# Importing CSV dataset
df = pd.read_csv("studentsperformance.csv")

# %%
df.set_index('parental_level_of_education', inplace=True)
df.head()
# Out:
#                              gender   age         lunch  \
# parental_level_of_education
# bachelor's degree            female  28.0      standard
# some college                 female  23.0      standard
# master's degree              female  19.0      standard
# associate's degree             male  28.0  free/reduced
# some college                   male  23.0      standard
#
#                             test_preparation_course  maths_score  \
# parental_level_of_education
# bachelor's degree                              none           72
# some college                              completed           69
# master's degree                                none           90
# associate's degree                             none           47
# some college                                   none           76
#
#                              reading_score  writing_score
# parental_level_of_education
# bachelor's degree                       72             74
# some college                            90             88
# master's degree                         95             93
# associate's degree                      57             44
# some college                            78             75

# %%
df
df.loc["high school"]   #will return high school indexed rows
# Out:
#                              gender   age         lunch  \
# parental_level_of_education
# high school                    male  29.0  free/reduced
# high school                  female  24.0  free/reduced
# high school                  female  30.0      standard
# high school                    male  22.0      standard
# high school                    male  24.0      standard
# ...                             ...   ...           ...
# high school                    male  23.0      standard
# high school                    male  25.0  free/reduced
# high school                    male  24.0      standard
# high school                    male  28.0  free/reduced
# high school                  female  21.0  free/reduced
#
#                             test_preparation_course  maths_score  \
# parental_level_of_education
# high school                               completed           64
# high school                                    none           38
# high school                                    none           65
# high school                                    none           88
# high school                                    none           66
# ...                                             ...          ...
# high school                                    none           57
# high school                               completed           86
# high school                                    none           63
# high school                                    none           62
# high school                               completed           59
#
#                              reading_score  writing_score
# parental_level_of_education
# high school                             64             67
# high school                             60             50
# high school                             81             73
# high school                             89             86
# high school                             69             63
# ...                                    ...            ...
# high school                             51             54
# high school                             81             75
# high school                             63             62
# high school                             55             55
# high school                             71             65
#
# [196 rows x 7 columns]

# %%
df.iloc[10]     #will return entire row details at index 10 using `.iloc[]`
# Out:
# gender                         male
# age                            22.0
# lunch                      standard
# test_preparation_course        none
# maths_score                      58
# reading_score                    54
# writing_score                    52
# Name: associate's degree, dtype: object

# %%
df.iloc[18:28]      #will return entire row details at index 10 till 28 using `.iloc[]`
# Out:
#                              gender   age         lunch  \
# parental_level_of_education
# master's degree                male  25.0  free/reduced
# associate's degree           female  22.0  free/reduced
# high school                    male  24.0      standard
# some college                 female  25.0  free/reduced
# some college                   male  25.0      standard
# some high school             female  27.0      standard
# bachelor's degree              male  24.0  free/reduced
# master's degree                male  25.0  free/reduced
# some college                   male  23.0      standard
# bachelor's degree            female  21.0      standard
#
#                             test_preparation_course  maths_score  \
# parental_level_of_education
# master's degree                           completed           46
# associate's degree                             none           54
# high school                                    none           66
# some college                              completed           65
# some college                                   none           44
# some high school                               none           69
# bachelor's degree                         completed           74
# master's degree                                none           73
# some college                                   none           69
# bachelor's degree                              none           67
#
#                              reading_score  writing_score
# parental_level_of_education
# master's degree                         42             46
# associate's degree                      58             61
# high school                             69             63
# some college                            75             70
# some college                            54             53
# some high school                        73             73
# bachelor's degree                       71             80
# master's degree                         74             72
# some college                            54             55
# bachelor's degree                       69             75
